# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing()

# %%
df
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 20640\n\n:Number of Attributes: 8 numeric, predictive attributes and the target\n\n:Attribute Information:\n    - MedInc        median income in block group\n    - HouseAge      median house age in block group\n    - AveRooms      average number of rooms per household\n    - AveBedrms     average number of bedrooms per household\n    - Population    block group population\n    - AveOccup      average number of household members\n    - Latitude      block group latitude\n    - Longitude     block group longitude\n\n:Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,000).\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical unit for which the U.S.\nCensus Bureau publishes sample data (a block group typically has a population\nof 600 to 3,000 people).\n\nA household is a group of people residing within a home. Since the average\nnumber of rooms and bedrooms in this dataset are provided per household, these\ncolumns may take surprisingly large values for block groups with few households\nand many empty houses, such as vacation resorts.\n\nIt can be downloaded/loaded using the\n:func:`sklearn.datasets.fetch_california_housing` function.\n\n.. rubric:: References\n\n- Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\n  Statistics and Probability Letters, 33 (1997) 291-297\n'}

# %%
dataset = pd.DataFrame(df.data)

# %%
dataset
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# ...       ...   ...       ...       ...     ...       ...    ...     ...
# 20635  1.5603  25.0  5.045455  1.133333   845.0  2.560606  39.48 -121.09
# 20636  2.5568  18.0  6.114035  1.315789   356.0  3.122807  39.49 -121.21
# 20637  1.7000  17.0  5.205543  1.120092  1007.0  2.325635  39.43 -121.22
# 20638  1.8672  18.0  5.329513  1.171920   741.0  2.123209  39.43 -121.32
# 20639  2.3886  16.0  5.254717  1.162264  1387.0  2.616981  39.37 -121.24
#
# [20640 rows x 8 columns]

# %%
dataset.columns = df.feature_names

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
x = dataset
y = df.target

# %%
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 30)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4523   2.8000      47.0  3.764205   1.116477      1557.0  4.423295     34.04
# 7682   3.1397      33.0  4.400000   0.970149      1205.0  3.597015     33.93
# 4033   7.8392      36.0  7.762774   1.083942       761.0  2.777372     34.17
# 4416   1.7945      50.0  2.653333   0.977778      2183.0  3.234074     34.08
# 18127  6.4480      30.0  6.641026   0.967949       467.0  2.993590     37.34
# ...       ...       ...       ...        ...         ...       ...       ...
# 500    1.5817      52.0  5.438017   1.173554       875.0  2.410468     37.85
# 12077  6.2308       2.0  8.801008   1.373804      5964.0  3.004534     33.87
# 15277  4.3182      17.0  6.744417   1.285360       815.0  2.022333     33.06
# 4517   1.8224      44.0  3.750670   1.034853      1419.0  3.804290     34.04
# 5925   5.5423      14.0  6.777969   1.078313      3699.0  3.183305     34.15
#
#        Longitude
# 4523     -118.21
# 7682     -118.10
# 4033     -118.55
# 4416     -118.26
# 18127    -122.02
# ...          ...
# 500      -122.27
# 12077    -117.64
# 15277    -117.34
# 4517     -118.20
# 5925     -117.80
#
# [14448 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.56208817,  1.45104424, -0.64926869, ...,  0.11361189,
#         -0.74289367,  0.67456162],
#        [-0.38368478,  0.34415253, -0.40030101, ...,  0.04283741,
#         -0.79452969,  0.72948735],
#        [ 2.08439507,  0.58134361,  0.91650925, ..., -0.0273685 ,
#         -0.68186927,  0.50479118],
#        ...,
#        [ 0.23523896, -0.92086658,  0.51773643, ..., -0.09204089,
#         -1.20292373,  1.1089742 ],
#        [-1.0755034 ,  1.21385316, -0.65456851, ...,  0.06059137,
#         -0.74289367,  0.67955486],
#        [ 0.87811087, -1.15805766,  0.53087493, ...,  0.00740135,
#         -0.69125764,  0.87928479]])

# %%
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
mse = cross_val_score(regression, x_train, y_train, scoring = 'neg_mean_squared_error', cv = 10)

# %%
mse.mean()
# Out:
# -0.5141134214304458

# %%
reg_pred = regression.predict(x_test)

# %%
reg_pred
# Out:
# array([1.18752976, 2.5790328 , 2.05946725, ..., 2.30125948, 2.29671606,
#        2.24049316])

# %%
import seaborn as sns

# %%
sns.displot(reg_pred-y_test, kind = 'kde')

# %% [raw]
# We can see in this dataset most of values of diff between predicted and test lies between -2 and 2 so dataset is good

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(reg_pred, y_test)

# %%
score
# Out:
# 0.2879099639033855

# %% [markdown]
# **Ridge Regression Algorithm**

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.model_selection import GridSearchCV

# %%
ridge_regressor = Ridge()

# %%
ridge_regressor
# Out:
# Ridge()

# %%
parameters = {'alpha':[1,2,5,10,20,30,40,50,80,90]}
ridgecv = GridSearchCV(ridge_regressor, parameters, scoring = 'neg_mean_squared_error', cv = 5)
ridgecv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 5, 10, 20, 30, 40, 50, 80, 90]},
#              scoring='neg_mean_squared_error')

# %%
print(ridgecv.best_params_)
# Out:
# {'alpha': 40}

# %%
print(ridgecv.best_score_)
# Out:
# -0.5141977491922176

# %%
ridgecv.predict(x_test)
# Out:
# array([1.19542089, 2.57709547, 2.0579304 , ..., 2.29046087, 2.31919285,
#        2.24439526])

# %%
sns.displot(ridgecv.predict(x_test)-y_test, kind = 'kde')

# %%
score1 = r2_score(ridgecv.predict(x_test), y_test)

# %%
score1
# Out:
# 0.2753844045646755

# %% [markdown]
# **Lasso**

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso()
lasso
# Out:
# Lasso()

# %%
parameters = {'alpha':[1,2,5,10,20,30,40,50,80,90]}
lassocv = GridSearchCV(lasso, parameters, scoring = 'neg_mean_squared_error', cv = 5)
lassocv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1, 2, 5, 10, 20, 30, 40, 50, 80, 90]},
#              scoring='neg_mean_squared_error')

# %%
print(lassocv.best_params_)
# Out:
# {'alpha': 1}

# %%
print(lassocv.best_score_)
# Out:
# -1.3110574888215487

# %%
lasso_pred = lassocv.predict(x_test)

# %%
lasso_pred
# Out:
# array([2.05913875, 2.05913875, 2.05913875, ..., 2.05913875, 2.05913875,
#        2.05913875])

# %%
sns.displot(lasso_pred-y_test, kind = 'kde')

# %%
score2 = r2_score(lasso_pred, y_test)
score2
# Out:
# 0.0
